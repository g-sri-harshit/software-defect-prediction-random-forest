# %%
import pandas as pd
import numpy as np

train = pd.read_excel('C:\\Users\\sriha\\OneDrive\\Desktop\\train_Fault.xlsx')
test = pd.read_excel('C:\\Users\\sriha\\OneDrive\\Desktop\\test.xlsx')

print("Train data shape :",train.shape)
print("Test data shape :",test.shape)

y = train["Fault"]
X = train.drop(columns=["Fault"])
X_test = test.copy()
# Out:
# Train data shape : (4236, 19)
# Test data shape : (1816, 19)

# %%
X = X.select_dtypes(include=["int64", "float64"])
X_test = X_test.select_dtypes(include=["int64", "float64"])

# %%
X_test = X_test[X.columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_val,y_train,y_val = train_test_split(
    X,y,
    test_size = 0.2,
    stratify = y,
    random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)

# %%
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (3388, 17) (848, 17) (1816, 17)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    class_weight="balanced"
)

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
from sklearn.metrics import f1_score

# %%
y_pred = model.predict(X_val)
f1 = f1_score(y_val, y_pred, average="macro")

print("Macro F1:", f1)
# Out:
# Macro F1: 0.6753784583260831

# %%
X_full = scaler.fit_transform(X)
model.fit(X_full, y)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
test_predictions = model.predict(X_test)
# Out:
# [0 0 0 ... 0 1 0]

# %%
import numpy as np
print(np.unique(y_pred, return_counts=True))
# Out:
# (array([0, 1], dtype=int64), array([394, 454], dtype=int64))

# %%
test_preds = model.predict(X_test)
print(test_preds.shape)
# Out:
# (1816,)

# %%
print(test.columns)
# Out:
# Index(['Issue-id', 'totalMethods', 'totalFields', 'nosi', 'loc', 'returnQty',
#        'loopQty', 'comparisonsQty', 'tryCatchQty', 'parenthesizedExpsQty',
#        'stringLiteralsQty', 'numbersQty', 'assignmentsQty',
#        'mathOperationsQty', 'variablesQty', 'maxNestedBlocks',
#        'uniqueWordsQty', 'Generated Postmortem', 'Fault'],
#       dtype='object')

# %%
submission = pd.DataFrame({
    "Issue-ID": test["Issue-id"],   # IMPORTANT: real Issue-ID
    "Fault": test_preds
})

submission.to_csv("submissionfinal.csv", index=False)
